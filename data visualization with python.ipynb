# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [1,2,3]
y = [1,4,9]
plt.plot(x,y)
plt.show(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.cos(x)
y = np.sin(y)
plt.plot(x,'b')
plt.plot(y,'r')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
contri =[17,8.8,12.75,14]
houses = ['vidya','krishna','namrata','karuna']
plt.pie(contri,labels = houses)

plt.show()
